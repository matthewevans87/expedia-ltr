# %%
# Quick eval script — run this instead of retraining
import json, yaml
import pandas as pd
import tensorflow as tf
from src.tf_data import fill_missing
from src.two_tower_train import retrieval_recall_at_k  # after patching

with open("configs/twotower_v1.yaml") as f:
    cfg = yaml.safe_load(f)

val_df = pd.read_parquet("data/processed/v1/val.parquet")
query_tower = tf.saved_model.load("runs/twotower_v1/query_tower")
item_tower  = tf.saved_model.load("runs/twotower_v1/item_tower")

metrics = retrieval_recall_at_k(
    query_tower, item_tower, val_df, cfg["data"], k_values=[5, 10, 20]
)
print(metrics)
with open("runs/twotower_v1/metrics.json", "w") as f:
    json.dump(metrics, f, indent=2)
# Out:
# /
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       2 # Quick eval script — run this instead of retraining
#       3 import json, yaml
#       4 import pandas as pd
#       5 import tensorflow as tf
# ----> 6 from src.tf_data import fill_missing
#       7 from src.two_tower_train import retrieval_recall_at_k  # after patching
#       8
#       9 with open("configs/twotower_v1.yaml") as f:
#
# ModuleNotFoundError: No module named 'src.tf_data'
